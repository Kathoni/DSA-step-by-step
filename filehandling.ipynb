# %%
# creating a new directory using python
import os
new_directory='package'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created")
# Out:
# Directory 'package' created

# %%
# List files and directories
items=os.listdir('.')
print(items)
# Out:
# ['.git', 'filehandling.ipynb', 'functions.py', 'list.py', 'package', 'packages', 'README.md']

# %%
## Joining paths
dir_name='folder'
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
path='example.txt'
if os.path.exists(path):
    print(f"The Path'{path}'exists")
else:
    print(f"The path '{path}' doesnot exist")
# Out:
# The path 'example.txt' doesnot exist
